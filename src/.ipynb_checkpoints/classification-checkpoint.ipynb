# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import losses
from tensorflow.keras import optimizers

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

print(tf.__version__)
# Out:
# 2.0.0

# %%
img_rows = 75
img_cols = 75
epochs = 15
batch_size = 32
num_of_train_samples = 800
num_of_test_samples = 798

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'dataset/train',
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

test_generator = test_datagen.flow_from_directory(
    'dataset/test',
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

validation_generator = test_generator
# Out:
# Found 800 images belonging to 2 classes.
# Found 798 images belonging to 2 classes.

# %%
input_image, image_label = train_generator.next()
for i in range(4):
    image = input_image[i]
    print("Airplane" if image_label[i][0] else "Motorbike")
    plt.imshow(image)
    plt.show()
# Out:
# Airplane
# Motorbike
# Motorbike
# Airplane

# %%
model = Sequential(name="object-classification")

model.add(Conv2D(128, (5, 5), input_shape=(img_rows, img_cols, 3), padding='valid'))
model.add(Conv2D(128, (5, 5), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='valid'))
model.add(Conv2D(64, (3, 3), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='valid'))
model.add(Conv2D(32, (3, 3), padding='valid'))
model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

# model.add(Dense(128))
# model.add(Activation('relu'))

# model.add(Dropout(0.5))

model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation('softmax'))

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.1),
              loss=losses.mean_squared_error, 
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "object-classification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 71, 71, 128)       9728
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 67, 67, 128)       409728
# _________________________________________________________________
# activation_26 (Activation)   (None, 67, 67, 128)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 33, 33, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 31, 31, 64)        73792
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# activation_27 (Activation)   (None, 29, 29, 64)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 12, 12, 32)        18464
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 10, 10, 32)        9248
# _________________________________________________________________
# activation_28 (Activation)   (None, 10, 10, 32)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               102528
# _________________________________________________________________
# activation_29 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# activation_30 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 130
# _________________________________________________________________
# activation_31 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 668,802
# Trainable params: 668,802
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=num_of_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=num_of_test_samples // batch_size)
# Out:
# Epoch 1/15
# 25/25 [==============================] - 8s 304ms/step - loss: 0.2326 - accuracy: 0.6137 - val_loss: 0.1811 - val_accuracy: 0.6302
# Epoch 2/15
# 25/25 [==============================] - 5s 216ms/step - loss: 0.1694 - accuracy: 0.7500 - val_loss: 0.0473 - val_accuracy: 0.9766
# Epoch 3/15
# 25/25 [==============================] - 5s 214ms/step - loss: 0.1241 - accuracy: 0.8300 - val_loss: 0.0416 - val_accuracy: 0.9596
# Epoch 4/15
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0793 - accuracy: 0.9000 - val_loss: 0.0283 - val_accuracy: 0.9648
# Epoch 5/15
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0661 - accuracy: 0.9087 - val_loss: 0.0257 - val_accuracy: 0.9635
# Epoch 6/15
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0513 - accuracy: 0.9438 - val_loss: 0.0235 - val_accuracy: 0.9727
# Epoch 7/15
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0388 - accuracy: 0.9563 - val_loss: 0.0238 - val_accuracy: 0.9740
# Epoch 8/15
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0409 - accuracy: 0.9488 - val_loss: 0.0116 - val_accuracy: 0.9857
# Epoch 9/15
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0352 - accuracy: 0.9550 - val_loss: 0.0076 - val_accuracy: 0.9922
# Epoch 10/15
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0354 - accuracy: 0.9463 - val_loss: 0.0099 - val_accuracy: 0.9883
# Epoch 11/15
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0265 - accuracy: 0.9700 - val_loss: 0.0091 - val_accuracy: 0.9896
# Epoch 12/15
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0200 - accuracy: 0.9737 - val_loss: 0.0078 - val_accuracy: 0.9922
# Epoch 13/15
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0247 - accuracy: 0.9700 - val_loss: 0.0069 - val_accuracy: 0.9922
# Epoch 14/15
# 25/25 [==============================] - 5s 215ms/step - loss: 0.0258 - accuracy: 0.9650 - val_loss: 0.0061 - val_accuracy: 0.9922
# Epoch 15/15
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0297 - accuracy: 0.9613 - val_loss: 0.0041 - val_accuracy: 0.9935

# %%
print(history.history.keys())

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
Y_pred = model.predict_generator(test_generator, num_of_test_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))

print('Classification Report')
target_names = ['Airplane', 'Motorbike']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[398   2]
#  [  3 395]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Airplane       0.99      0.99      0.99       400
#    Motorbike       0.99      0.99      0.99       398
#
#     accuracy                           0.99       798
#    macro avg       0.99      0.99      0.99       798
# weighted avg       0.99      0.99      0.99       798

# %%
def prediction_check(array):
    if array[0][0] > array[0][1]:
        return "Airplane"
    else:
        return "Motorbike"

input_image, image_label = test_generator.next()
count=0
for i in range(500):
    image = input_image[i]
    predictions = model.predict(np.expand_dims(image, axis=0))
    print("Prediction: {}".format(prediction_check(predictions)))
    print("Correct: {}".format("Airplane" if image_label[i][0] else "Motorbike"))
    if()
    plt.imshow(image)
    plt.show()
# Out:
# Prediction: Airplane
# Correct: Airplane
# Prediction: Motorbike
# Correct: Motorbike
# Prediction: Airplane
# Correct: Airplane
# Prediction: Motorbike
# Correct: Motorbike

# %%
model.save_weights('CNN.h5')

# %%
from tensorflow import math
confusion = confusion_matrix(test_generator.classes,y_pred)
print(confusion)
# Out:
# [[346  54]
#  [  0 398]]
